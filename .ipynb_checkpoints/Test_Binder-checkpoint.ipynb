# %% [markdown]
# # Test binder by deploying a simple Jupyter Notebook
# ### First, begin my importing required modules

# %%
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Use widgets to make interactive plot.

# %%
# %matplotlib notebook

x = np.linspace(-2 * np.pi, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(phase_arg = 1.0, amplitude = 1):
    line.set_ydata(amplitude * np.sin(phase_arg * x))
    fig.canvas.draw_idle()
    ax.set_ylim([-5, 5])

interact(update);
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=1.0, description='phase_arg', max=3.0, min=-1.0), IntSlider(value=1, description='amplitude', max=3, min=-1), Output()), _dom_classes=('widget-interact',))
